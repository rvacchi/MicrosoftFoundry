# %% [markdown]
# ## Calling our OpenAI Model from Microsoft Foundry

# %% [markdown]
# ### Installing Required Libraries

# %%
# %pip install azure-ai-projects==2.0.0b2 openai==1.109.1 python-dotenv azure-identity

# %% [markdown]
# ### Setting up the Environment Variables

# %%
import os
from dotenv import load_dotenv
from azure.identity import DefaultAzureCredential
from azure.ai.projects import AIProjectClient
load_dotenv()

foundry_project_endpoint = os.getenv("FOUNDRY_PROJECT_ENDPOINT")
model_deployment_name = os.getenv("MODEL_DEPLOYMENT_NAME")

# %% [markdown]
# ### Setting up the AI Foundry Project Client

# %%
project_client = AIProjectClient(
    endpoint=foundry_project_endpoint,
    credential=DefaultAzureCredential()
)

# %% [markdown]
# ### Setting up the OpenAI Client

# %%
openai_client = project_client.get_openai_client()

# %% [markdown]
# ### Sending a Request to the OpenAI Model

# %%
response = openai_client.responses.create(
    model=model_deployment_name,
    instructions="You are a helpful AI assistant.",
    input = "Can you tell me about Microsoft Foundry?"
)

print(f"Response output: {response.output_text}")
# Out:
# Response output: Microsoft Foundry is an innovation and development program run by Microsoft that focuses on creating and experimenting with new ideas in software, technology, and user experience design. It's a platform designed to foster creativity, collaboration, and rapid prototyping among engineers, designers, and project managers. Foundry often works on early-stage, experimental projects and technologies that align with Microsoft's broader strategic goals.
#
# ### Key Features of Microsoft Foundry:
# 1. **Incubator Program:** Foundry serves as an incubator where teams work on small, experimental projects to test ideas and develop prototypes for new products or features.
#
# 2. **Focus on Innovation:** It emphasizes exploring innovative solutions for emerging technologies, including artificial intelligence, cloud computing, productivity tools, and collaboration platforms.
#
# 3. **Cross-Disciplinary Collaboration:** Foundry brings together diverse teams, including developers, product managers, researchers, and designers. This collaborative environment helps build solutions with different perspectives and expertise.
#
# 4. **Internship Opportunities:** Foundry is known for offering internship programs designed to recruit talented students and early-career professionals. These interns participate in cutting-edge projects while gaining mentorship and hands-on experience in technology development.
#
# 5. **Agile Development:** Teams within Foundry work in an agile and transparent environment, allowing them to quickly create, test, and refine solutions without traditional corporate constraints.
#
# 6. **Impactful Contributions:** While the projects might be experimental, many of them influence larger initiatives within Microsoft or contribute ideas that find their way into real-world products and services.
#
# Foundry operates in major Microsoft locations, such as Vancouver, Canada. It’s viewed as an entry point for talent and innovation while supporting Microsoft's larger strategy to stay ahead in the rapidly-evolving tech landscape. Specific details and projects within Foundry can vary depending on the location and scope of the program at any given time.
